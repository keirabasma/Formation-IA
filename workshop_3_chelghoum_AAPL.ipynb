# %% [markdown]
# <a href="https://colab.research.google.com/github/keirabasma/Formation-IA/blob/main/workshop_3_chelghoum_AAPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8b215ea3-3c89-45fa-bd3d-5fcc08ddf582" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b215ea3-3c89-45fa-bd3d-5fcc08ddf582">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("cars (1).csv")
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven seller_type fuel_type transmission_type  mileage  engine  max_power  seats   price
# 0           0    Maruti Alto   Maruti      Alto            9     120000  Individual    Petrol            Manual    19.70     796      46.30      5  120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000  Individual    Petrol            Manual    18.90    1197      82.00      5  550000
# 2           2    Hyundai i20  Hyundai       i20           11      60000  Individual    Petrol            Manual    17.00    1197      80.00      5  215000
# 3           3    Maruti Alto   Maruti      Alto            9      37000  Individual    Petrol            Manual    20.92     998      67.10      5  226000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer    Diesel            Manual    22.77    1498      98.59      5  570000

# %%
df.groupby("brand")["price"].mean()
# Out:
# brand
# Audi             1.966865e+06
# BMW              2.693827e+06
# Bentley          9.266667e+06
# Datsun           3.205176e+05
# Ferrari          3.950000e+07
# Force            7.000000e+05
# Ford             6.452241e+05
# Honda            6.177569e+05
# Hyundai          5.761539e+05
# ISUZU            1.897500e+06
# Isuzu            1.355000e+06
# Jaguar           2.643034e+06
# Jeep             1.795805e+06
# Kia              1.735250e+06
# Land Rover       3.823902e+06
# Lexus            5.146500e+06
# MG               1.752947e+06
# Mahindra         7.874550e+05
# Maruti           4.870893e+05
# Maserati         6.100000e+06
# Mercedes-AMG     5.100000e+06
# Mercedes-Benz    2.480742e+06
# Mini             2.182647e+06
# Nissan           9.553636e+05
# Porsche          5.161190e+06
# Renault          4.409851e+05
# Rolls-Royce      2.420000e+07
# Skoda            7.840898e+05
# Tata             6.835349e+05
# Toyota           1.371317e+06
# Volkswagen       5.165468e+05
# ...

# %%
df.groupby("fuel_type").size()
# Out:
# fuel_type
# CNG          301
# Diesel      7419
# Electric       4
# LPG           44
# Petrol      7643
# dtype: int64

# %%
df.groupby("brand")["mileage"].count()
# Out:
# brand
# Audi              192
# BMW               439
# Bentley             3
# Datsun            170
# Ferrari             1
# Force               1
# Ford              790
# Honda            1485
# Hyundai          2982
# ISUZU               2
# Isuzu               8
# Jaguar             59
# Jeep               41
# Kia                32
# Land Rover         51
# Lexus              10
# MG                 19
# Mahindra         1011
# Maruti           4992
# Maserati            2
# Mercedes-AMG        1
# Mercedes-Benz     337
# Mini               17
# Nissan             11
# Porsche            21
# Renault           536
# Rolls-Royce         1
# Skoda             334
# Tata              430
# Toyota            793
# Volkswagen        620
# Volvo              20
# Name: mileage, dtype: int64

# %%
df.groupby("fuel_type")["price"].agg(["mean", "min", "max"])
# Out:
#                    mean      min       max
# fuel_type
# CNG        4.176877e+05   125000   1080000
# Diesel     1.000469e+06   100000   9200000
# Electric   1.853500e+06  1699000   2000000
# LPG        2.062727e+05    80000    420000
# Petrol     5.728619e+05    40000  39500000

# %%
df.groupby("transmission_type").agg({
    "price": "mean",
    "km_driven": "mean",
    "mileage": "mean"
})
# Out:
#                           price     km_driven    mileage
# transmission_type
# Automatic          1.579557e+06  48184.767106  17.391008
# Manual             5.652852e+05  57553.285481  20.303206

# %%
pd.pivot_table(
    df,
    values="price",
    index="brand",
    columns="fuel_type",
    aggfunc="mean"
)
# Out:
# fuel_type                CNG        Diesel   Electric            LPG        Petrol
# brand
# Audi                     NaN  1.951424e+06        NaN            NaN  2.086182e+06
# BMW                      NaN  2.715868e+06        NaN            NaN  2.495955e+06
# Bentley                  NaN           NaN        NaN            NaN  9.266667e+06
# Datsun                   NaN           NaN        NaN            NaN  3.205176e+05
# Ferrari                  NaN           NaN        NaN            NaN  3.950000e+07
# Force                    NaN  7.000000e+05        NaN            NaN           NaN
# Ford                     NaN  6.785722e+05        NaN            NaN  5.731920e+05
# Honda          422000.000000  6.191512e+05        NaN            NaN  6.175078e+05
# Hyundai        435416.666667  6.946809e+05        NaN  247769.230769  5.134466e+05
# ISUZU                    NaN  1.897500e+06        NaN            NaN           NaN
# ...

# %%
df.groupby("brand")["price"].mean().sort_values(ascending=False)
# Out:
# brand
# Ferrari          3.950000e+07
# Rolls-Royce      2.420000e+07
# Bentley          9.266667e+06
# Maserati         6.100000e+06
# Porsche          5.161190e+06
# Lexus            5.146500e+06
# Mercedes-AMG     5.100000e+06
# Land Rover       3.823902e+06
# Volvo            3.729700e+06
# BMW              2.693827e+06
# Jaguar           2.643034e+06
# Mercedes-Benz    2.480742e+06
# Mini             2.182647e+06
# Audi             1.966865e+06
# ISUZU            1.897500e+06
# Jeep             1.795805e+06
# MG               1.752947e+06
# Kia              1.735250e+06
# Toyota           1.371317e+06
# Isuzu            1.355000e+06
# Nissan           9.553636e+05
# Mahindra         7.874550e+05
# Skoda            7.840898e+05
# Force            7.000000e+05
# Tata             6.835349e+05
# Ford             6.452241e+05
# Honda            6.177569e+05
# Hyundai          5.761539e+05
# Volkswagen       5.165468e+05
# Maruti           4.870893e+05
# Renault          4.409851e+05
# ...
