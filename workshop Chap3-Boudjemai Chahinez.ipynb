# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

sns.set(style="whitegrid")

# %%
import pandas as pd

df = pd.read_csv(r"C:/Users/Chahinez/Downloads/AAPL.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1  2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2  2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3  2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4  2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
df.shape
df.dtypes
df.describe()
df.columns
df.isna().sum()
np.mean(df["Close"])
# Out:
# np.float64(127.35266294565217)

# %%
plt.figure(figsize=(12,6))
plt.plot(df["Close"])
plt.title("AAPL - Closing Price Over Time")
plt.xlabel("Time Index")
plt.ylabel("Close Price")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Close"], bins=30)
plt.title("Distribution of Close Price")
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
numeric_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x="High", y="Low")
plt.title("High vs Low Prices")
plt.show()

# %%
fig = px.line(df, y="Close", title="AAPL Closing Price (Interactive)")
fig.show()

# %%
fig = px.scatter(df, x="High", y="Low", color="Volume",
                 title="High vs Low with Volume")
fig.show()

# %%
fig = go.Figure(data=[go.Candlestick(
    open=df['Open'],
    high=df['High'],
    low=df['Low'],
    close=df['Close']
)])

fig.update_layout(title="AAPL Candlestick Chart")
fig.show()
